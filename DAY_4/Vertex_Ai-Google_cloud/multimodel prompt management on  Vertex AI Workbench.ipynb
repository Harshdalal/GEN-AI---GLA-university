# %%
# !pip install streamlit google-generativeai pandas


code = '''
import streamlit as st
import pandas as pd
import google.generativeai as genai

# Configure Gemini API key
GOOGLE_API_KEY = "AIzaSyA2JAHidciNxDbzC-R25DqRFzuQWq6mzIw"
genai.configure(api_key=GOOGLE_API_KEY)

model = genai.GenerativeModel("gemini-1.5-flash")

# UI
st.title("🧪 Gemini Prompt Testing App")
st.markdown("Test and compare prompts on a sample text using Gemini 1.5 Flash.")

# Sample input text
sample_text = st.text_area("📝 Input Text", height=200, value="""I ordered the headphones last week and they arrived two days late. The sound quality is great, but the packaging was damaged. Customer support was helpful and replaced the box.""")

# Multiple prompt inputs
num_prompts = st.number_input("How many prompts to test?", min_value=1, max_value=10, value=3)
prompts = []
for i in range(num_prompts):
    prompt = st.text_input(f"Prompt {i+1}", key=f"prompt_{i}")
    if prompt:
        prompts.append(prompt)

# Run evaluation
if st.button("🚀 Evaluate Prompts"):
    results = []
    for idx, prompt_text in enumerate(prompts):
        full_prompt = f"{prompt_text}\n\n{sample_text}"
        try:
            response = model.generate_content(full_prompt)
            output = response.text.strip()
        except Exception as e:
            output = f"Error: {e}"

        results.append({
            "Prompt #": idx+1,
            "Prompt Used": prompt_text,
            "Model Output": output
        })

    df = pd.DataFrame(results)
    st.dataframe(df)

    # Download results
    csv = df.to_csv(index=False).encode("utf-8")
    st.download_button("Download CSV", csv, "prompt_results.csv", "text/csv")
'''
with open("app.py", "w") as f:
    f.write(code)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 69.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 139.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [streamlit]/6 [streamlit]
# ...

# %%
# !streamlit run app.py --server.port 8501 --server.enableCORS false
# Out:
# 2025-07-25 14:44:46.116
# ...
# 'server.enableXsrfProtection=true'.
# As a result, 'server.enableCORS' is being overridden to 'true'.
#
# More information:
# In order to protect against CSRF attacks, we send a cookie with each request.
# To do so, we must specify allowable origins, which places a restriction on
# cross-origin resource sharing.
#
# If cross origin resource sharing is required, please disable server.enableXsrfProtection.
#
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://10.128.0.6:8501
#   External URL: http://34.132.43.207:8501

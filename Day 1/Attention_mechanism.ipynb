# %% [markdown]
# #Basic Attention Mechanism with LSTM Encoder-Decoder

# %% [markdown]
# #✅ Overview:
#
# We implement the Bahdanau-style (additive) attention manually to enhance the LSTM model using teacher forcing.
#
# 📦 Step-by-Step Implementation
#
# 1. Install Libraries

# %%
# !pip install tensorflow numpy pandas
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %% [markdown]
# #2. Prepare Data

# %%
# Import necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Define a small parallel English-Hindi toy dataset
data = [
    ["hello", "नमस्ते"],
    ["how are you", "आप कैसे हैं"],
    ["i am fine", "मैं ठीक हूँ"],
    ["what is your name", "आपका नाम क्या है"],
    ["my name is john", "मेरा नाम जॉन है"],
    ["thank you", "धन्यवाद"],
    ["good morning", "सुप्रभात"],
    ["good night", "शुभ रात्रि"]
]

# Separate English and Hindi texts into two lists
eng_texts, hin_texts = zip(*data)

# Add special start-of-sentence (<sos>) and end-of-sentence (<eos>) tokens to Hindi texts
hin_texts_input = ['<sos> ' + txt for txt in hin_texts]  # For decoder input
hin_texts_output = [txt + ' <eos>' for txt in hin_texts]  # For decoder output (target)

# Initialize tokenizers for English and Hindi
eng_tokenizer = Tokenizer()               # Default filters remove punctuation and lowercase text
hin_tokenizer = Tokenizer(filters='')     # Hindi tokenizer with no filters (to preserve characters)

# Fit tokenizers on respective text data
eng_tokenizer.fit_on_texts(eng_texts)
hin_tokenizer.fit_on_texts(hin_texts_input + hin_texts_output)  # Combine input & output for full vocabulary

# Convert text sequences into integer sequences and pad them to uniform length
eng_seq = pad_sequences(eng_tokenizer.texts_to_sequences(eng_texts), padding='post')         # English input
hin_seq_input = pad_sequences(hin_tokenizer.texts_to_sequences(hin_texts_input), padding='post')   # Hindi decoder input
hin_seq_output = pad_sequences(hin_tokenizer.texts_to_sequences(hin_texts_output), padding='post') # Hindi decoder output

# Calculate vocabulary sizes (+1 for padding/UNK token)
eng_vocab = len(eng_tokenizer.word_index) + 1
hin_vocab = len(hin_tokenizer.word_index) + 1

# Display the shape of the final English sequence matrix
print("Input shape:", eng_seq.shape)
# Out:
# Input shape: (8, 4)

# %% [markdown]
# #3. Define Encoder, Decoder with Bahdanau Attention

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, dot, Activation
from tensorflow.keras.models import Model

# Set the dimensionality of the LSTM hidden units
latent_dim = 256

# ------------------------ ENCODER ------------------------

# Input layer for encoder sequence (English sentences)
enc_input = Input(shape=(None,))  # variable-length input

# Embedding layer to learn word embeddings for encoder input
enc_emb = Embedding(input_dim=eng_vocab, output_dim=latent_dim)(enc_input)

# LSTM layer returns full sequence and final hidden + cell states
# enc_lstm: all hidden states for every time step (used for attention)
# enc_h, enc_c: final hidden and cell states (used to initialize decoder)
enc_lstm, enc_h, enc_c = LSTM(latent_dim, return_sequences=True, return_state=True)(enc_emb)

# Store final states to initialize decoder
enc_states = [enc_h, enc_c]

# ------------------------ DECODER ------------------------

# Input layer for decoder sequence (Hindi input with <sos>)
dec_input = Input(shape=(None,))  # variable-length output sequence

# Embedding layer for decoder input
dec_emb = Embedding(input_dim=hin_vocab, output_dim=latent_dim)(dec_input)

# LSTM decoder receives encoder's final states as initial state
# dec_lstm: all decoder time-step outputs
dec_lstm, _, _ = LSTM(latent_dim, return_sequences=True, return_state=True)(dec_emb, initial_state=enc_states)

# ------------------------ ATTENTION ------------------------

# Compute attention scores using dot product between decoder output and encoder output
# score shape: (batch_size, dec_seq_len, enc_seq_len)
score = dot([dec_lstm, enc_lstm], axes=[2, 2])

# Normalize attention scores to get probabilities
attention_weights = Activation('softmax')(score)  # softmax over encoder steps

# Multiply attention weights with encoder hidden states to get context vector
# context_vector shape: (batch_size, dec_seq_len, latent_dim)
context_vector = dot([attention_weights, enc_lstm], axes=[2, 1])

# ------------------------ CONCATENATION & OUTPUT ------------------------

# Concatenate decoder output and context vector for each time step
# shape becomes (batch_size, dec_seq_len, latent_dim * 2)
dec_concat = Concatenate()([context_vector, dec_lstm])

# Final output layer: softmax over vocabulary to predict next word
output = Dense(hin_vocab, activation='softmax')(dec_concat)

# Define the complete model taking encoder and decoder inputs
model = Model([enc_input, dec_input], output)

# Compile model with Adam optimizer and sparse categorical crossentropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# Print model architecture
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, None, 256) │      4,608 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 256) │      5,120 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, None,     │    525,312 │ embedding[0][0]   │
# │                     │ 256), (None,      │            │                   │
# │                     │ 256), (None,      │            │                   │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, None,     │    525,312 │ embedding_1[0][0… │
# │                     │ 256), (None,      │            │ lstm[0][1],       │
# │                     │ 256), (None,      │            │ lstm[0][2]        │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dot (Dot)           │ (None, None,      │          0 │ lstm_1[0][0],     │
# │                     │ None)             │            │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, None,      │          0 │ dot[0][0]         │
# │ (Activation)        │ None)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dot_1 (Dot)         │ (None, None, 256) │          0 │ activation[0][0], │
# │                     │                   │            │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, None, 512) │          0 │ dot_1[0][0],      │
# │ (Concatenate)       │                   │            │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, None, 20)  │     10,260 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,070,612 (4.08 MB)
#  Trainable params: 1,070,612 (4.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #4. Train the Model

# %%
hin_seq_output = np.expand_dims(hin_seq_output, -1)
model.fit([eng_seq, hin_seq_input], hin_seq_output, epochs=300, batch_size=2)
# Out:
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 2.9742
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 2.7970
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 2.4747
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2.0572
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.9061
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 1.8022
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.8159
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5852
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.5441
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.5087
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.1143
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.1772
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.1375
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.0064
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.8616
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.0294
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.9411
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.8070
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.7799
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.6079
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4591
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.5250
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4115
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3945
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3106
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2701
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2357
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2055
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1962
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1415
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1598
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1181
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0921
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0747
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0865
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0499
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0539
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0417
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0354
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0280
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0284
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0231
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0210
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0222
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0164
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0186
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0208
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0198
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0171
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0151
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0132
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0142
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0136
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0106
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0114
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0094
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0107
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0088
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0093
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0076
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0079
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0091
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0078
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0075
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0072
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0060
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0068
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0048
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0070
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0055
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0052
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0052
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0048
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0050
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0042
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0044
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0037
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0038
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0048
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0044
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0041
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0037
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0036
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0038
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0040
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0030
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0031
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0032
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0031
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0032
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0028
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0028
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0027
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0027
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0030
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0028
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0024
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0029
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0020
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0022
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0024
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0026
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0022
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0023
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0022
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0022
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0020
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0022
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0020
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0022
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0021
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0019
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0016
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0020
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0021
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0018
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0018
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0016
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0016
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0016
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0014
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0015
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0013
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0018
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0013
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0017
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0014
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0016
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0014
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0016
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0014
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0012
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0014
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0014
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0012
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0014
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0012
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0012
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0014
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0011
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0012
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0013
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0012
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0013
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0012
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0011
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0010
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0011
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0012
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0010
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0012
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0011
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0011
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 8.0926e-04
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 9.9700e-04
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 9.3895e-04
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0010
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 8.4009e-04
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0010
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0011
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 9.6292e-04
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 9.7384e-04
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 8.3529e-04
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 9.3364e-04
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 8.6093e-04
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 6.9448e-04
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 8.2213e-04
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 8.1015e-04
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 8.0116e-04
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 8.1915e-04
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 9.2927e-04
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7.0871e-04
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 8.6709e-04
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 7.2865e-04
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 7.2429e-04
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 7.8584e-04
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 7.1676e-04
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 7.4611e-04
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 7.0960e-04
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 6.9083e-04
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 7.0931e-04
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 7.8383e-04
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6.6336e-04
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.7331e-04
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7.3291e-04
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 6.8122e-04
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 7.7106e-04
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 6.9984e-04
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 7.5255e-04
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 6.2990e-04
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 6.5969e-04
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 6.1835e-04
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 5.7425e-04
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 5.1596e-04
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 6.7296e-04
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 5.7441e-04
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.7983e-04
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 5.3198e-04
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 6.0629e-04
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.6000e-04
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5.8525e-04
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 5.4180e-04
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.2729e-04
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 5.4341e-04
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 5.0891e-04
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 6.1260e-04
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 5.6553e-04
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 5.1681e-04
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 5.4306e-04
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5.0543e-04
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 5.4809e-04
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5.4851e-04
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 4.8254e-04
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4.6092e-04
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 5.3931e-04
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 5.3346e-04
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 4.6083e-04
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 5.4510e-04
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4.5431e-04
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 4.6988e-04
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5.2248e-04
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5.1939e-04
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4.7513e-04
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 5.0907e-04
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 5.1522e-04
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 4.6887e-04
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4.3365e-04
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 5.0811e-04
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4.5717e-04
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4.6536e-04
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4.2193e-04
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4.8414e-04
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 4.2876e-04
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 4.6578e-04
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 4.6410e-04
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 4.1770e-04
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 4.0744e-04
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 4.7622e-04
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 3.9579e-04
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 3.5475e-04
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 4.1598e-04
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 3.3657e-04
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 4.3241e-04
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.8705e-04
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.9478e-04
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.9915e-04
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.8938e-04
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.9785e-04
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 3.4758e-04
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.4441e-04
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.7923e-04
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.3613e-04
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 3.5958e-04
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.5460e-04
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.1704e-04
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.1622e-04
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.6187e-04
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 3.5897e-04
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.7807e-04
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3.5442e-04
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 3.7248e-04
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.5977e-04
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.2939e-04
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3.5589e-04
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.5294e-04
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 3.8963e-04
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3.6369e-04
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.1348e-04
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.3002e-04
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 3.3794e-04
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.4501e-04
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.3534e-04
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.8825e-04
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.9625e-04
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3.3716e-04
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.3500e-04
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3.5113e-04
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3.4921e-04
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3.1375e-04
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.0624e-04
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.2773e-04
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 2.8644e-04
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 3.0088e-04
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2.5843e-04
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 3.1593e-04
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 2.7926e-04
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 2.8984e-04
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 3.3254e-04
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2.7735e-04
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.6745e-04
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.7080e-04
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.9792e-04
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.6868e-04
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.5910e-04
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.7557e-04
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.8929e-04
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.4224e-04
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.6982e-04
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.6744e-04
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.3215e-04

# %% [markdown]
# #Luong Attention Mechanism
#
# ✅ Overview:
#
# Luong attention is a multiplicative method where we align decoder hidden state with all encoder states using dot product.
#
# 📦 Step-by-Step Implementation
#
# 1. Add Luong Attention Mechanism

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, dot, Activation
from tensorflow.keras.models import Model

latent_dim = 256  # Dimensionality of LSTM hidden states and embeddings

# ---------------- Encoder ----------------
# Define input layer for the encoder (English sentence)
enc_input = Input(shape=(None,))

# Embed the input words (word index → dense vector)
enc_emb = Embedding(input_dim=eng_vocab, output_dim=latent_dim)(enc_input)

# Pass the embeddings to LSTM. Return the full sequence, and the final hidden and cell states
enc_output, enc_h, enc_c = LSTM(latent_dim, return_sequences=True, return_state=True)(enc_emb)
# enc_output: sequence of encoder hidden states (for attention)
# enc_h, enc_c: final states to initialize decoder

# ---------------- Decoder ----------------
# Define input layer for the decoder (Hindi sentence)
dec_input = Input(shape=(None,))

# Embed the decoder input words
dec_emb = Embedding(input_dim=hin_vocab, output_dim=latent_dim)(dec_input)

# Pass embeddings to LSTM, initializing with encoder's final states
dec_output, _, _ = LSTM(latent_dim, return_sequences=True, return_state=True)(dec_emb, initial_state=[enc_h, enc_c])
# dec_output: sequence of decoder hidden states

# ---------------- Luong Attention (Dot Product) ----------------
# Calculate attention scores via dot product between decoder and encoder outputs
score = dot([dec_output, enc_output], axes=[2, 2])  # shape: (batch_size, dec_seq_len, enc_seq_len)

# Apply softmax to get attention weights
attention_weights = Activation('softmax')(score)  # shape: (batch_size, dec_seq_len, enc_seq_len)

# Multiply attention weights with encoder outputs to get context vectors
context = dot([attention_weights, enc_output], axes=[2, 1])  # shape: (batch_size, dec_seq_len, latent_dim)

# ---------------- Context + Decoder Output ----------------
# Concatenate context vectors with decoder LSTM outputs
combined = Concatenate()([context, dec_output])  # shape: (batch_size, dec_seq_len, 2*latent_dim)

# Final Dense layer to generate probabilities over the Hindi vocabulary
output = Dense(hin_vocab, activation='softmax')(combined)

# ---------------- Model Compilation ----------------
# Define the full model with encoder and decoder inputs
model = Model([enc_input, dec_input], output)

# Compile the model with Adam optimizer and sparse categorical crossentropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# Display the model architecture summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, None, 256) │      4,608 │ input_layer_2[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, None, 256) │      5,120 │ input_layer_3[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, None,     │    525,312 │ embedding_2[0][0] │
# │                     │ 256), (None,      │            │                   │
# │                     │ 256), (None,      │            │                   │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    525,312 │ embedding_3[0][0… │
# │                     │ 256), (None,      │            │ lstm_2[0][1],     │
# │                     │ 256), (None,      │            │ lstm_2[0][2]      │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dot_2 (Dot)         │ (None, None,      │          0 │ lstm_3[0][0],     │
# │                     │ None)             │            │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, None,      │          0 │ dot_2[0][0]       │
# │ (Activation)        │ None)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dot_3 (Dot)         │ (None, None, 256) │          0 │ activation_1[0][… │
# │                     │                   │            │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, None, 512) │          0 │ dot_3[0][0],      │
# │ (Concatenate)       │                   │            │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, None, 20)  │     10,260 │ concatenate_1[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,070,612 (4.08 MB)
#  Trainable params: 1,070,612 (4.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #2. Train Luong Attention Model

# %%
model.fit([eng_seq, hin_seq_input], hin_seq_output, epochs=300, batch_size=2)
# Out:
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 2.9818
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.8569
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.6389
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.0010
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.9935
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.7375
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.6733
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.4793
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.4000
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.2380
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.5020
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.1172
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.1500
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.1038
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.0110
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.9777
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.8571
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.6879
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.7787
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.6372
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.6353
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.5963
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.4215
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3442
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3344
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3252
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2655
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2559
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2282
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1899
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1721
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1136
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1291
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1084
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0740
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0781
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0527
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0511
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0387
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0370
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0391
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0351
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0316
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0209
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0251
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0185
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0205
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0190
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0175
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0148
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0178
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0159
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0156
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0105
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0092
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0117
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0115
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0101
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0088
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0081
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0078
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0104
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0075
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0070
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0068
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0072
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0065
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0078
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0065
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0054
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0057
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0055
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0049
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0043
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0051
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0051
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0057
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0041
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0037
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0038
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0045
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0037
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0046
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0040
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0040
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0036
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0035
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0040
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0031
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0032
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0033
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0029
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0030
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0028
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0025
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0028
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0026
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0027
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0025
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0023
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0025
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0023
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0021
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.